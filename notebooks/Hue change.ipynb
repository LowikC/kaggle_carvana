# %%
import cv2
import numpy as np
from PIL import Image

# %%
img = cv2.imread("../data/train_480x320/3c6acfceb552_04.png")

# %%
Image.fromarray(img)
# Out:
# <PIL.Image.Image image mode=RGB size=480x320 at 0x7F86A379E518>

# %%
im_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

# %%
im_hsv
# Out:
# array([[[  0,   0, 252],
#         [  0,   0, 252],
#         [  0,   0, 252],
#         ...,
#         [  0,   0, 249],
#         [  0,   0, 249],
#         [  0,   0, 249]],
#
#        [[  0,   0, 252],
#         [  0,   0, 252],
#         [  0,   0, 252],
#         ...,
#         [  0,   0, 249],
#         [  0,   0, 249],
#         [  0,   0, 249]],
#
#        [[  0,   0, 252],
#         [  0,   0, 252],
#         [  0,   0, 252],
#         ...,
#         [  0,   0, 249],
#         [  0,   0, 249],
#         [  0,   0, 249]],
#
#        ...,
#        [[  0,   0, 219],
#         [  0,   0, 219],
#         [  0,   0, 219],
#         ...,
#         [ 83,   5, 220],
#         [ 83,   5, 220],
#         [ 83,   5, 220]],
#
#        [[  0,   0, 219],
#         [  0,   0, 219],
#         [  0,   0, 219],
#         ...,
#         [ 83,   5, 220],
#         [ 83,   5, 220],
#         [ 83,   5, 220]],
#
#        [[  0,   0, 219],
#         [  0,   0, 219],
#         [  0,   0, 219],
#         ...,
#         [ 83,   5, 220],
#         [ 83,   5, 220],
#         [ 83,   5, 220]]], dtype=uint8)

# %%
im_hsv[..., 0] += 30

# %%
im_bgr = cv2.cvtColor(im_hsv, cv2.COLOR_HSV2BGR)

# %%
Image.fromarray(im_bgr)
# Out:
# <PIL.Image.Image image mode=RGB size=480x320 at 0x7F86A379EA58>
